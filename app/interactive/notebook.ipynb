# %%
from interactive.django_setup import start_django_in_notebook
from interface import models
start_django_in_notebook()

# %%
from api.urls import generator as G
x=G.EndpointGenerator(model=models.Description)

# %%
v = x.get_view()
v.serializer_class.Meta.model
# Out:
# interface.models.Description

# %%
from interface import models as interface_models
from waterquality import models as wq_models
y=G.ApiEndpoints([interface_models,wq_models])
x = y.get_endpoints()

# %%
x
# Out:
# [<URLPattern '^v0/interface/description/$' [name='v0/interface/description-list']>,
#  <URLPattern '^v0/interface/description/(?P<pk>[^/.]+)/$' [name='v0/interface/description-detail']>,
#  <URLPattern '^v0/interface/geometry/$' [name='v0/interface/geometry-list']>,
#  <URLPattern '^v0/interface/geometry/(?P<pk>[^/.]+)/$' [name='v0/interface/geometry-detail']>,
#  <URLPattern '^v0/interface/parameter/$' [name='v0/interface/parameter-list']>,
#  <URLPattern '^v0/interface/parameter/(?P<pk>[^/.]+)/$' [name='v0/interface/parameter-detail']>,
#  <URLPattern '^v0/interface/predicaterelation/$' [name='v0/interface/predicaterelation-list']>,
#  <URLPattern '^v0/interface/predicaterelation/(?P<pk>[^/.]+)/$' [name='v0/interface/predicaterelation-detail']>,
#  <URLPattern '^v0/interface/property/$' [name='v0/interface/property-list']>,
#  <URLPattern '^v0/interface/property/(?P<pk>[^/.]+)/$' [name='v0/interface/property-detail']>,
#  <URLPattern '^v0/waterquality/analysismethod/$' [name='v0/waterquality/analysismethod-list']>,
#  <URLPattern '^v0/waterquality/analysismethod/(?P<pk>[^/.]+)/$' [name='v0/waterquality/analysismethod-detail']>,
#  <URLPattern '^v0/waterquality/catchment/$' [name='v0/waterquality/catchment-list']>,
#  <URLPattern '^v0/waterquality/catchment/(?P<pk>[^/.]+)/$' [name='v0/waterquality/catchment-detail']>,
#  <URLPattern '^v0/waterquality/fraction/$' [name='v0/waterquality/fraction-list']>,
#  <URLPattern '^v0/waterquality/fraction/(?P<pk>[^/.]+)/$' [name='v0/waterquality/fraction-detail']>,
#  <URLPattern '^v0/waterquality/institution/$' [name='v0/waterquality/institution-list']>,
#  <URLPattern '^v0/waterquality/institution/(?P<pk>[^/.]+)/$' [name='v0/waterquality/institution-detail']>,
#  <URLPattern '^v0/waterquality/qualityflag/$' [name='v0/waterquality/qualityflag-list']>,
#  <URLPattern '^v0/waterquality/qualityflag/(?P<pk>[^/.]+)/$' [name='v0/waterquality/qualityflag-detail']>,
#  <URLPattern '^v0/waterquality/sample/$' [name='v0/waterquality/sample-list']>,
#  <URLPattern '^v0/waterquality/sample/(?P<pk>[^/.]+)/$' [name='v0/waterquality/sample-detail']>,
#  <URLPattern '^v0/waterquality/samplevalue/$' [name='v0/waterquality/samplevalue-list']>,
#  <URLPattern '^v0/waterquality/samplevalue/(?P<pk>[^/.]+)/$' [name='v0/waterquality/samplevalue-detail']>,
#  <URLPattern '^v0/waterquality/sampling/$' [name='v0/waterquality/sampling-list']>,
#  <URLPattern '^v0/waterquality/sampling/(?P<pk>[^/.]+)/$' [name='v0/waterquality/sampling-detail']>,
#  <URLPattern '^v0/waterquality/unit/$' [name='v0/waterquality/unit-list']>,
#  <URLPattern '^v0/waterquality/unit/(?P<pk>[^/.]+)/$' [name='v0/waterquality/unit-detail']>,
#  <URLPattern '^v0/waterquality/waterbody/$' [name='v0/waterquality/waterbody-list']>,
#  <URLPattern '^v0/waterquality/waterbody/(?P<pk>[^/.]+)/$' [name='v0/waterquality/waterbody-detail']>]

# %%
x.get_router_url()
# Out:
# [<URLPattern '^description/$' [name='description-list']>,
#  <URLPattern '^description\.(?P<format>[a-z0-9]+)/?$' [name='description-list']>,
#  <URLPattern '^description/(?P<pk>[^/.]+)/$' [name='description-detail']>,
#  <URLPattern '^description/(?P<pk>[^/.]+)\.(?P<format>[a-z0-9]+)/?$' [name='description-detail']>,
#  <URLPattern '' [name='api-root']>,
#  <URLPattern '<drf_format_suffix:format>' [name='api-root']>]

# %%
geom = models.Geometry.objects.first()

# %%
geom.points.json
# Out:
# '{ "type": "MultiPoint", "coordinates": [ [ 0.035555444007662, -0.014331888714457 ], [ 0.004133910221901, -0.008873059136812 ], [ 0.017713159686878, -0.013737453536988 ], [ 0.020468630473888, -0.007662198057978 ], [ 0.013430736303207, -0.009133483561782 ], [ 0.023334755979107, -0.01211159641021 ], [ 0.022114941116006, -0.017837805974091 ] ] }'

# %%
# !cd .. && python3 manage.py makemigrations
# Out:
# No changes detected

# %%
# !cd .. && python3 manage.py collectstatic --noinput
# Out:
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureType : <class 'sensorthings.models.FeatureType'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperty : <class 'sensorthings.models.ObservedProperty'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedure : <class 'sensorthings.models.PreparationProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationStep : <class 'sensorthings.models.PreparationStep'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7f30c7497f60>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## meta : <module 'wqdms.meta' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/wqdms/meta.py'>
# <class 'module'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureType'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperty'>, <class 'sensorthings.models.PreparationProcedure'>, <class 'sensorthings.models.PreparationStep'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureType : <class 'sensorthings.models.FeatureType'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperty : <class 'sensorthings.models.ObservedProperty'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedure : <class 'sensorthings.models.PreparationProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationStep : <class 'sensorthings.models.PreparationStep'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7f30c7497f60>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## meta : <module 'wqdms.meta' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/wqdms/meta.py'>
# <class 'module'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureType'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperty'>, <class 'sensorthings.models.PreparationProcedure'>, <class 'sensorthings.models.PreparationStep'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureType : <class 'sensorthings.models.FeatureType'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperty : <class 'sensorthings.models.ObservedProperty'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedure : <class 'sensorthings.models.PreparationProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationStep : <class 'sensorthings.models.PreparationStep'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f30be6ed850>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7f30c7497f60>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## meta : <module 'wqdms.meta' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/wqdms/meta.py'>
# <class 'module'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureType'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperty'>, <class 'sensorthings.models.PreparationProcedure'>, <class 'sensorthings.models.PreparationStep'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# The model Thing is already registered in app 'sensorthings'.
# The model User is already registered with 'auth.UserAdmin'.
#
# 188 static files copied to '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/static'.

# %%
# !cd .. && . cli.sh && cmd_wqdms_backend_mig
# Out:
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7ea86afdb380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7ea86afdb380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7ea862116810>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x7ea86afdb380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# The model Thing is already registered in app 'sensorthings'.
# The model User is already registered with 'auth.UserAdmin'.
# Migrations for 'sensorthings':
#   sensorthings/migrations/0001_initial.py
#     + Create model Feature
#     + Create model Datastream
#     + Create model FeatureTypes
#     + Create model Location
#     + Create model Observation
#     + Create model ObservedProperties
#     + Create model PreparationProcedures
#     + Create model PreparationSteps
#     + Create model RelationRole
#     + Create model RelatedObservation
#     + Create model RelatedFeature
#     + Create model RelatedDatastream
#     + Create model Sampler
#     + Create model Sampling
#     + Add field creator_sampling to feature
#     + Create model SamplingProcedure
#     + Add field procedure to sampling
#     + Create model Sensor
#     + Add field sensor to datastream
#     + Create model Thing
#     + Add field thing to sampling
#     + Create model RelatedThing
#     + Create model HistLocation
#     + Add field thing to datastream
# Migrations for 'waterquality':
#   waterquality/migrations/0001_initial.py
#     + Create model AnalysisMethod
#     + Create model Catchment
#     + Create model Fraction
#     + Create model Institution
#     + Create model QualityFlag
#     + Create model Sample
#     + Create model SampleValue
#     + Create model Sampling
#     + Create model Unit
#     + Create model Waterbody
# Migrations for 'interface':
#   interface/migrations/0001_initial.py
#     + Create model Description
#     + Create model Geometry
#     + Create model Parameter
#     + Create model PredicateRelation
#     + Create model Property
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x77cf0c4bf380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x77cf0c4bf380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# ## BEFORE_SAVE : before_save
# <class 'str'>
# ## Datastream : <class 'sensorthings.models.Datastream'>
# <class 'django.db.models.base.ModelBase'>
# ## Feature : <class 'sensorthings.models.Feature'>
# <class 'django.db.models.base.ModelBase'>
# ## FeatureTypes : <class 'sensorthings.models.FeatureTypes'>
# <class 'django.db.models.base.ModelBase'>
# ## HistLocation : <class 'sensorthings.models.HistLocation'>
# <class 'django.db.models.base.ModelBase'>
# ## LifecycleModelMixin : <class 'django_lifecycle.mixins.LifecycleModelMixin'>
# <class 'type'>
# ## Location : <class 'sensorthings.models.Location'>
# <class 'django.db.models.base.ModelBase'>
# ## Observation : <class 'sensorthings.models.Observation'>
# <class 'django.db.models.base.ModelBase'>
# ## ObservedProperties : <class 'sensorthings.models.ObservedProperties'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationProcedures : <class 'sensorthings.models.PreparationProcedures'>
# <class 'django.db.models.base.ModelBase'>
# ## PreparationSteps : <class 'sensorthings.models.PreparationSteps'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedDatastream : <class 'sensorthings.models.RelatedDatastream'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedFeature : <class 'sensorthings.models.RelatedFeature'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedObservation : <class 'sensorthings.models.RelatedObservation'>
# <class 'django.db.models.base.ModelBase'>
# ## RelatedThing : <class 'sensorthings.models.RelatedThing'>
# <class 'django.db.models.base.ModelBase'>
# ## RelationRole : <class 'sensorthings.models.RelationRole'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampler : <class 'sensorthings.models.Sampler'>
# <class 'django.db.models.base.ModelBase'>
# ## Sampling : <class 'sensorthings.models.Sampling'>
# <class 'django.db.models.base.ModelBase'>
# ## SamplingProcedure : <class 'sensorthings.models.SamplingProcedure'>
# <class 'django.db.models.base.ModelBase'>
# ## Sensor : <class 'sensorthings.models.Sensor'>
# <class 'django.db.models.base.ModelBase'>
# ## SystemAbstractModel : <class 'sensorthings.models.SystemAbstractModel'>
# <class 'django.db.models.base.ModelBase'>
# ## Thing : <class 'sensorthings.models.Thing'>
# <class 'django.db.models.base.ModelBase'>
# ## User : <class 'django.contrib.auth.models.User'>
# <class 'django.db.models.base.ModelBase'>
# ## __builtins__ : {'__name__': 'builtins', '__doc__': "Built-in functions, types, exceptions, and other objects.\n\nThis module provides direct access to all 'built-in'\nidentifiers of Python; for example, builtins.len is\nthe full name for the built-in function len().\n\nThis module is not normally accessed explicitly by most\napplications, but can be useful in modules that provide\nobjects with the same name as a built-in value, but in\nwhich the built-in of that name is also needed.", '__package__': '', '__loader__': <class '_frozen_importlib.BuiltinImporter'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>, origin='built-in'), '__build_class__': <built-in function __build_class__>, '__import__': <built-in function __import__>, 'abs': <built-in function abs>, 'all': <built-in function all>, 'any': <built-in function any>, 'ascii': <built-in function ascii>, 'bin': <built-in function bin>, 'breakpoint': <built-in function breakpoint>, 'callable': <built-in function callable>, 'chr': <built-in function chr>, 'compile': <built-in function compile>, 'delattr': <built-in function delattr>, 'dir': <built-in function dir>, 'divmod': <built-in function divmod>, 'eval': <built-in function eval>, 'exec': <built-in function exec>, 'format': <built-in function format>, 'getattr': <built-in function getattr>, 'globals': <built-in function globals>, 'hasattr': <built-in function hasattr>, 'hash': <built-in function hash>, 'hex': <built-in function hex>, 'id': <built-in function id>, 'input': <built-in function input>, 'isinstance': <built-in function isinstance>, 'issubclass': <built-in function issubclass>, 'iter': <built-in function iter>, 'aiter': <built-in function aiter>, 'len': <built-in function len>, 'locals': <built-in function locals>, 'max': <built-in function max>, 'min': <built-in function min>, 'next': <built-in function next>, 'anext': <built-in function anext>, 'oct': <built-in function oct>, 'ord': <built-in function ord>, 'pow': <built-in function pow>, 'print': <built-in function print>, 'repr': <built-in function repr>, 'round': <built-in function round>, 'setattr': <built-in function setattr>, 'sorted': <built-in function sorted>, 'sum': <built-in function sum>, 'vars': <built-in function vars>, 'None': None, 'Ellipsis': Ellipsis, 'NotImplemented': NotImplemented, 'False': False, 'True': True, 'bool': <class 'bool'>, 'memoryview': <class 'memoryview'>, 'bytearray': <class 'bytearray'>, 'bytes': <class 'bytes'>, 'classmethod': <class 'classmethod'>, 'complex': <class 'complex'>, 'dict': <class 'dict'>, 'enumerate': <class 'enumerate'>, 'filter': <class 'filter'>, 'float': <class 'float'>, 'frozenset': <class 'frozenset'>, 'property': <class 'property'>, 'int': <class 'int'>, 'list': <class 'list'>, 'map': <class 'map'>, 'object': <class 'object'>, 'range': <class 'range'>, 'reversed': <class 'reversed'>, 'set': <class 'set'>, 'slice': <class 'slice'>, 'staticmethod': <class 'staticmethod'>, 'str': <class 'str'>, 'super': <class 'super'>, 'tuple': <class 'tuple'>, 'type': <class 'type'>, 'zip': <class 'zip'>, '__debug__': True, 'BaseException': <class 'BaseException'>, 'BaseExceptionGroup': <class 'BaseExceptionGroup'>, 'Exception': <class 'Exception'>, 'GeneratorExit': <class 'GeneratorExit'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'SystemExit': <class 'SystemExit'>, 'ArithmeticError': <class 'ArithmeticError'>, 'AssertionError': <class 'AssertionError'>, 'AttributeError': <class 'AttributeError'>, 'BufferError': <class 'BufferError'>, 'EOFError': <class 'EOFError'>, 'ImportError': <class 'ImportError'>, 'LookupError': <class 'LookupError'>, 'MemoryError': <class 'MemoryError'>, 'NameError': <class 'NameError'>, 'OSError': <class 'OSError'>, 'ReferenceError': <class 'ReferenceError'>, 'RuntimeError': <class 'RuntimeError'>, 'StopAsyncIteration': <class 'StopAsyncIteration'>, 'StopIteration': <class 'StopIteration'>, 'SyntaxError': <class 'SyntaxError'>, 'SystemErr ...
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved., 'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information., 'license': Type license() to see the full license text, 'help': Type help() for interactive help, or help(object) for help about object.}
# <class 'dict'>
# ## __cached__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/__pycache__/models.cpython-312.pyc
# <class 'str'>
# ## __doc__ : None
# <class 'NoneType'>
# ## __file__ : /home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py
# <class 'str'>
# ## __loader__ : <_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>
# <class '_frozen_importlib_external.SourceFileLoader'>
# ## __name__ : sensorthings.models
# <class 'str'>
# ## __package__ : sensorthings
# <class 'str'>
# ## __spec__ : ModuleSpec(name='sensorthings.models', loader=<_frozen_importlib_external.SourceFileLoader object at 0x77cf036fee70>, origin='/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py')
# <class '_frozen_importlib.ModuleSpec'>
# ## get_user_model : <function get_user_model at 0x77cf0c4bf380>
# <class 'function'>
# ## gis_models : <module 'django.contrib.gis.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/gis/db/models/__init__.py'>
# <class 'module'>
# ## hook : <class 'django_lifecycle.decorators.HookConfig'>
# <class 'type'>
# ## models : <module 'django.db.models' from '/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/db/models/__init__.py'>
# <class 'module'>
# [<class 'sensorthings.models.Thing'>, <class 'sensorthings.models.Datastream'>, <class 'sensorthings.models.Feature'>, <class 'sensorthings.models.FeatureTypes'>, <class 'sensorthings.models.HistLocation'>, <class 'sensorthings.models.Location'>, <class 'sensorthings.models.Observation'>, <class 'sensorthings.models.ObservedProperties'>, <class 'sensorthings.models.PreparationProcedures'>, <class 'sensorthings.models.PreparationSteps'>, <class 'sensorthings.models.RelatedDatastream'>, <class 'sensorthings.models.RelatedFeature'>, <class 'sensorthings.models.RelatedObservation'>, <class 'sensorthings.models.RelatedThing'>, <class 'sensorthings.models.RelationRole'>, <class 'sensorthings.models.Sampler'>, <class 'sensorthings.models.Sampling'>, <class 'sensorthings.models.SamplingProcedure'>, <class 'sensorthings.models.Sensor'>, <class 'sensorthings.models.Thing'>, <class 'django.contrib.auth.models.User'>]
# The model Thing is already registered in app 'sensorthings'.
# The model User is already registered with 'auth.UserAdmin'.
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, interface, sensorthings, sessions, waterquality
# Running migrations:
#   Applying contenttypes.0001_initial... OK
#   Applying auth.0001_initial... OK
#   Applying admin.0001_initial... OK
#   Applying admin.0002_logentry_remove_auto_add... OK
#   Applying admin.0003_logentry_add_action_flag_choices... OK
#   Applying contenttypes.0002_remove_content_type_name... OK
#   Applying auth.0002_alter_permission_name_max_length... OK
#   Applying auth.0003_alter_user_email_max_length... OK
#   Applying auth.0004_alter_user_username_opts... OK
#   Applying auth.0005_alter_user_last_login_null... OK
#   Applying auth.0006_require_contenttypes_0002... OK
#   Applying auth.0007_alter_validators_add_error_messages... OK
#   Applying auth.0008_alter_user_username_max_length... OK
#   Applying auth.0009_alter_user_last_name_max_length... OK
#   Applying auth.0010_alter_group_name_max_length... OK
#   Applying auth.0011_update_proxy_permissions... OK
#   Applying auth.0012_alter_user_first_name_max_length... OK
#   Applying interface.0001_initial... OK
#   Applying sensorthings.0001_initial... OK
#   Applying sessions.0001_initial... OK
#   Applying waterquality.0001_initial... OK

# %%
# !cd .. && python3 manage.py dumpdata
# Out:
# Traceback (most recent call last):
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/manage.py", line 22, in <module>
#     main()
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/manage.py", line 18, in main
#     execute_from_command_line(sys.argv)
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/core/management/__init__.py", line 442, in execute_from_command_line
#     utility.execute()
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/core/management/__init__.py", line 416, in execute
#     django.setup()
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/__init__.py", line 24, in setup
#     apps.populate(settings.INSTALLED_APPS)
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/apps/registry.py", line 124, in populate
#     app_config.ready()
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/admin/apps.py", line 27, in ready
#     self.module.autodiscover()
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/contrib/admin/__init__.py", line 52, in autodiscover
#     autodiscover_modules("admin", register_to=site)
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/.vpy/lib/python3.12/site-packages/django/utils/module_loading.py", line 58, in autodiscover_modules
#     import_module("%s.%s" % (app_config.name, module_to_search))
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/admin.py", line 3, in <module>
#     from sensorthings.models import (
# ImportError: cannot import name 'HistoricalLocation' from 'sensorthings.models' (/home/worker/apps/groupeffect/UNEP/repositories/wqdms-core/backend/sensorthings/models.py)

# %%
# !cd .. && python3 manage.py loaddata interactive/admin.json
# Out:
# Installed 1 object(s) from 1 fixture(s)
